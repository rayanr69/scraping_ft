# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re

url = "https://candidat.francetravail.fr/offres/emploi/data-analyst/s28m18"
page = requests.get(url)

soup = bs(page.content, 'html.parser')
soup

france_travail = soup.find_all("li" , class_="result")
france_travail 

titles_clean = []
description_clean = []
type_contrat_clean  = []
adress_clean = []
    
for france_travail in france_travail :
    
    titles_clean.append(france_travail.find("span", class_="media-heading-title").text)
    
    adress_clean.append(france_travail.find('p', class_="subtext").find("span").text)
    
    
    description_clean.append(france_travail.find('p' , class_="description").text)
    
    type_contrat_clean.append(france_travail.find('p', class_="contrat visible-xs").text)

df = pd.DataFrame({"Poste" : titles_clean , "Lieu" : adress_clean , "Description" : description_clean, "Contrat" : type_contrat_clean})
df
# Out:
#                                                 Poste                    Lieu  \
# 0                     Alternance - Data Analyst (H/F)             74 - CLUSES
# 1                                  Data Analyst (h/f)             64 - BORDES
# 2                                        Data analyst           Ile-de-France
# 3                                        Data analyst           Ile-de-France
# 4                              Data Analyst H/F (H/F)  92 - NEUILLY SUR SEINE
# 5                                        Data analyst           33 - BORDEAUX
# 6        Data Analyst « SAS, BOARD et Dataviz » (H/F)      75 - Paris (Dept.)
# 7                                        Data analyst             93 - PANTIN
# 8                                  DATA ANALYST (H/F)              79 - NIORT
# 9                 ALTERNANT DATA ANALYST (H/F) FPDA24         26 - ST VALLIER
# 10                        DATA BUSINESS ANALYST (H/F)           38 - GRENOBLE
# 11                        UN(e) DATA ANALYST(e) (H/F)           33 - BORDEAUX
# 12                                       Data analyst            69 - LYON 03
# 13                            Data analyst IARD (H/F)       93 - NOISY LE SEC
# 14  Chargé(e) d'étude - géomaticien / data analyst...         91 - MARCOUSSIS
# 15                                 Data analyst (F/H)              12 - RODEZ
# 16                      Consultant Data Analyst (H/F)           75 - PARIS 17
# 17                                       Data analyst  59 - VILLENEUVE D ASCQ
# 18              Procurement Data Analyst Junior (H/F)           92 - ST CLOUD
# 19                   Data Analyst en alternance (H/F)            69 - LYON 08
#
#                                           Description                  Contrat
# 0   Description de l'entreprise\n\nPartenaire de c...      CDD\n - Temps plein
# 1   Notre client SAFRNA HELICOPTER ENGINES recherc...  Intérim\n - Temps plein
# 2   ABALON recherche un(e) Data Analyste pour rejo...      CDI\n - Temps plein
# 3   ABALON recherche un(e) Data Analyste pour rejo...      CDI\n - Temps plein
# 4   Vous avez un profil de Data Analyst (H/F) ?\n\...      CDI\n - Temps plein
# 5   Nous recherchons un(e) Data Analyst talentueux...      CDI\n - Temps plein
# 6   Mon client est la Direction du Contrôle de Ges...      CDI\n - Temps plein
# 7   Le data analyst est rattaché à la direction de...      CDI\n - Temps plein
# 8   Nous recherchons notre DATA ANALYST h/f pour i...      CDI\n - Temps plein
# 9   Se présenter au stand DAHER de l'entreprise le...      CDD\n - Temps plein
# 10  Vous êtes un(e) Data Business Analyst confirmé...      CDI\n - Temps plein
# 11  CRIT bordeaux tertiaire recherche pour son cli...      CDD\n - Temps plein
# 12  En lien avec l'augmentation de son portefeuill...      CDI\n - Temps plein
# 13  Flash info. Le N°1 français des réseaux de cou...      CDI\n - Temps plein
# 14  La Fédération Française de Rugby (FFR) recherc...      CDI\n - Temps plein
# 15  Descriptif de la marque :\nExpectra, votre par...      CDI\n - Temps plein
# 16  Vous partagez notre passion pour les données, ...      CDI\n - Temps plein
# 17  Qui sommes-nous ?\n\nNous sommes passionnés pa...      CDI\n - Temps plein
# 18  CDS Groupe est le spécialiste français des sol...      CDD\n - Temps plein
# 19  JOURNEE PORTE OUVERTE LE 09/03 au 29 av Lecler...      CDD\n - Temps plein
